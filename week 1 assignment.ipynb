# %% [markdown]
# # Homeownership in America by Race Dataset
#  Title: S2502 | Demographic Characteristics For Occupied Housing Units
#
#  Source: 2019: American Community Survey 1-Year Estimates Subject Tables (https://data.census.gov/cedsci/table?q=homeownership&tid=ACSST1Y2019.S2502)
# ## Description
#  I downloaded this survey data to understand the demographics of housed persons in America. The data shows the race and education level of surveyed people. And the year the people moved into their housing is including. Most households moved into their residence as early as 2017 and later. Movement decreased around the same time of the 2008 financial crisis that affected the housing market between period of 2000-2009. But the movement continued to decline, slightly, until 2016. Interesting enough between the years of 2015 and 2016 almost reached the lowest percentages, like two oldest periods: 1990-1999 and 1989 and earlier.

# %%
import pandas as pd

# %%
pd.read_csv('homeownership.csv')
# Out:
#                                      Label (Grouping) Occupied housing units  \
# 0                              Occupied housing units            122,802,852
# 1       RACE AND HISPANIC OR LATINO ORIGIN OF HOUS...                    NaN
# 2                                         One race --                    NaN
# 3                                               White             93,145,172
# 4                           Black or African American             15,382,489
# 5                   American Indian and Alaska Native                952,313
# 6                                               Asian              6,052,073
# 7               Native Hawaiian and Other Pacific ...                170,390
# 8                                     Some other race              4,422,288
# 9                                   Two or more races              2,678,127
# 10                          Hispanic or Latino origin             16,681,970
# ...

# %%
ds = pd.read_csv('homeownership.csv')

# %%
import pandas as pdt

# %%
pdt.read_csv('race-year-census homeownership.csv')
# Out:
#                                      Label (Grouping)  \
# 0                              Occupied housing units
# 1       RACE AND HISPANIC OR LATINO ORIGIN OF HOUS...
# 2                                         One race --
# 3                                               White
# 4                           Black or African American
# 5                   American Indian and Alaska Native
# 6                                               Asian
# 7               Native Hawaiian and Other Pacific ...
# 8                                     Some other race
# 9                                   Two or more races
# 10                          Hispanic or Latino origin
# 11                White alone, not Hispanic or Latino
# 12                   YEAR HOUSEHOLDER MOVED INTO UNIT
# 13                             Moved in 2017 or later
# 14                              Moved in 2015 to 2016
# 15                              Moved in 2010 to 2014
# ...

# %%
dst = pdt.read_csv('race-year-census homeownership.csv')

# %%
dst.shape
# Out:
# (19, 5)

# %%
dst.info
# Out:
# <bound method DataFrame.info of                                      Label (Grouping)  \
# 0                              Occupied housing units
# 1       RACE AND HISPANIC OR LATINO ORIGIN OF HOUS...
# 2                                         One race --
# 3                                               White
# 4                           Black or African American
# 5                   American Indian and Alaska Native
# 6                                               Asian
# 7               Native Hawaiian and Other Pacific ...
# 8                                     Some other race
# 9                                   Two or more races
# 10                          Hispanic or Latino origin
# 11                White alone, not Hispanic or Latino
# 12                   YEAR HOUSEHOLDER MOVED INTO UNIT
# 13                             Moved in 2017 or later
# 14                              Moved in 2015 to 2016
# 15                              Moved in 2010 to 2014
# ...

# %%
dst.head()
# Out:
#                                     Label (Grouping)  \
# 0                             Occupied housing units
# 1      RACE AND HISPANIC OR LATINO ORIGIN OF HOUS...
# 2                                        One race --
# 3                                              White
# 4                          Black or African American
#
#   Owner-occupied housing units Percent owner-occupied housing units  \
# 0                   78,724,862                           78,724,862
# 1                          NaN                                  NaN
# 2                          NaN                                  NaN
# 3                   64,910,316                               82.50%
# 4                    6,456,629                                8.20%
#
#   Renter-occupied housing units Percent renter-occupied housing units
# 0                    44,077,990                            44,077,990
# 1                           NaN                                   NaN
# ...

# %%
#enbaling panda function and naming it "pdr"
import pandas as pdr

# %%
#enabling graphing feature and naming it plt
import matplotlib.pyplot as plt
#enables funtion to customize graph
# %matplotlib inline

# %%
#name dataset as pdr and read/show dataset
pdr.read_csv('race-census homeownership.csv')
# Out:
#                                           Race  Owner-occupied housing units  \
# 0                                        White                      64910316
# 1                    Black or African American                       6456629
# 2            American Indian and Alaska Native                        519905
# 3                                        Asian                       3666975
# 4   Native Hawaiian and Other Pacific Islander                         68306
# 5                              Some other race                       1793642
# 6                            Two or more races                       1309089
# 7                    Hispanic or Latino origin                       8019989
# 8          White alone, not Hispanic or Latino                      59102566
#
#    Renter-occupied housing units
# 0                       28234856
# 1                        8925860
# 2                         432408
# 3                        2385098
# ...

# %%
#name new dataframe with race as index and not as"0,1,2.."
dsrr=dsr.set_index("Race")

# %%
#plot dataframe with edits as bar graph
dsrr.plot(kind='bar')
#customize graph features to add x and y labels, title, and position graph legend
plt.ylabel('Number of Units (in millions)')
plt.xlabel('Race')
plt.title('Number of owned and rented housing units by race')
plt.legend(loc='upper right')
#display customized graph
plt.show()
#this bar graph shows that surveyed White people owner and rent a greater amount of untis than any other race,but also own units at a greater proportion thatn any other surveyed race as well.

# %%
#show orginal dataset's values and number of apperance
dsr.value_counts()
# Out:
# Race                                         Owner-occupied housing units  Renter-occupied housing units
# American Indian and Alaska Native            519905                        432408                           1
# Asian                                        3666975                       2385098                          1
# Black or African American                    6456629                       8925860                          1
# Hispanic or Latino origin                    8019989                       8661981                          1
# Two or more races                            1309089                       1369038                          1
# White                                        64910316                      28234856                         1
# White alone, not Hispanic or Latino          59102566                      22827646                         1
# ...

# %%
#querying data
newdata =dsrr.loc[['Black or African American','Asian','White'], 'Owner-occupied housing units']
#plot dataframe with edits as bar graph
newdata.plot(kind='bar')
#customize graph features to add x and y labels, title, and position graph legend
plt.ylabel('Number of Units (in millions)')
plt.xlabel('Race')
plt.title('Number of owned housing units by race')
plt.legend(loc='upper right')
#display customized graph
plt.show()
#this bar graph shows that surveyed White people own  more units than surveyed Black and Asian people
